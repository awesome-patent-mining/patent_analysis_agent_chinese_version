# %%
import asyncio
from llama_index.embeddings.openai.base import BaseEmbedding
import sys,os
import pandas as pd
from llama_index.llms.openai import OpenAI,utils

import asyncio
import nest_asyncio
nest_asyncio.apply()

# %%
sys.path.append(os.path.abspath('../..'))

# %%
from research_agent.core.generate_patent_chart import Patent_Chart_Generator
# Out:
# C:\Users\admin\anaconda3\envs\python_class_310\lib\site-packages\pydantic\_internal\_config.py:345: UserWarning: Valid config keys have changed in V2:
# * 'fields' has been removed
#   warnings.warn(message, UserWarning)

# %%
pat_chart_generator = Patent_Chart_Generator()
patent_info = pd.read_excel('C:/Users/admin/patent_survey_draft/20250320012345555.XLSX')
patent_application_trend_info = pat_chart_generator.retrieve_patent_trends_info(patent_info)
patent_application_trend_info_md = patent_application_trend_info.to_markdown(index=True)
tech_trend_analysis = await pat_chart_generator.generate_patent_application_trend_analysis(patent_application_trend_info_md)
image_path = '../../figs/patent_application_trend.jpg'
alt_text = 'Patent Application Trend'
title_text = 'Patent Application Trend'
pat_chart_generator.plot_patent_trends(patent_application_trend_info,file_dir=image_path)
with open('patent_analysis.md', 'w', encoding='utf-8') as file:
    markdown_image = f'![{alt_text}]({image_path} "{title_text}")\n'
    file.write(markdown_image)
    file.write(tech_trend_analysis)
# Out:
# C:\Users\admin\anaconda3\envs\python_class_310\lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
